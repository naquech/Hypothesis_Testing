# %% [markdown]
# # Tables to Dataframes

# %%
import sqlalchemy
import pandas as pd

from sqlalchemy import create_engine
from sqlalchemy.orm import Session, sessionmaker
from sqlalchemy import inspect

# %%
engine = create_engine('sqlite:///Northwind_small.sqlite', echo=True)
Session = sessionmaker(bind=engine)
session = Session()

# %%
con = engine.connect();
# Out:
# 2019-01-24 08:32:03,658 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-01-24 08:32:03,661 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-24 08:32:03,663 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-01-24 08:32:03,665 INFO sqlalchemy.engine.base.Engine ()

# %% [markdown]
# ----------------

# %% [markdown]
# ### Product

# %%
df_product = pd.read_sql_query('''select * from [Product]''', engine);
df_product.head(15)
# Out:
# 2019-01-24 19:13:26,247 INFO sqlalchemy.engine.base.Engine select * from [Product]
# INFO:sqlalchemy.engine.base.Engine:select * from [Product]
# 2019-01-24 19:13:26,251 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
#     Id                      ProductName  SupplierId  CategoryId  \
# 0    1                             Chai           1           1
# 1    2                            Chang           1           1
# 2    3                    Aniseed Syrup           1           2
# 3    4     Chef Anton's Cajun Seasoning           2           2
# 4    5           Chef Anton's Gumbo Mix           2           2
# 5    6     Grandma's Boysenberry Spread           3           2
# 6    7  Uncle Bob's Organic Dried Pears           3           7
# 7    8       Northwoods Cranberry Sauce           3           2
# 8    9                  Mishi Kobe Niku           4           6
# 9   10                            Ikura           4           8
# ...

# %%
df_product['ReorderLevel'].value_counts()
# Out:
# 0     24
# 25    12
# 15    10
# 30     8
# 20     8
# 5      8
# 10     7
# Name: ReorderLevel, dtype: int64

# %%
dfp_reord = pd.read_sql_query('''select p.Id, p.ReorderLevel, od.Discount from [Product] p join [OrderDetail] od
on p.Id=od.ProductId where Discount == 0.00''', engine)
dfp_reord
# Out:
# 2019-01-24 19:37:12,039 INFO sqlalchemy.engine.base.Engine select p.Id, p.ReorderLevel, od.Discount from [Product] p join [OrderDetail] od
# on p.Id=od.ProductId where Discount == 0.00
# INFO:sqlalchemy.engine.base.Engine:select p.Id, p.ReorderLevel, od.Discount from [Product] p join [OrderDetail] od
# on p.Id=od.ProductId where Discount == 0.00
# 2019-01-24 19:37:12,041 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
#       Id  ReorderLevel  Discount
# 0     11            30       0.0
# 1     42             0       0.0
# 2     72             0       0.0
# 3     14             0       0.0
# 4     51            10       0.0
# 5     41            10       0.0
# 6     65             0       0.0
# 7     60             0       0.0
# 8     31            20       0.0
# 9     39             5       0.0
# 10    49            15       0.0
# 11    74             5       0.0
# 12     2            25       0.0
# 13    16            10       0.0
# ...

# %%
dfp_reornod = pd.read_sql_query('''select p.Id, p.ReorderLevel, od.Discount from [Product] p join [OrderDetail] od
on p.Id=od.ProductId where Discount > 0.00''', engine)
dfp_reornod
# Out:
# 2019-01-24 19:37:17,676 INFO sqlalchemy.engine.base.Engine select p.Id, p.ReorderLevel, od.Discount from [Product] p join [OrderDetail] od
# on p.Id=od.ProductId where Discount > 0.00
# INFO:sqlalchemy.engine.base.Engine:select p.Id, p.ReorderLevel, od.Discount from [Product] p join [OrderDetail] od
# on p.Id=od.ProductId where Discount > 0.00
# 2019-01-24 19:37:17,679 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
#      Id  ReorderLevel  Discount
# 0    51            10      0.15
# 1    65             0      0.15
# 2    22            25      0.05
# 3    57            20      0.05
# 4    20             0      0.05
# 5    33            20      0.05
# 6    24             0      0.15
# 7    55            20      0.15
# 8     2            25      0.20
# 9     5             0      0.20
# 10   32            25      0.20
# 11   41            10      0.25
# 12   62             0      0.25
# 13   70            30      0.25
# 14    5             0      0.20
# ...

# %% [markdown]
# ----------

# %% [markdown]
# ### Order

# %%
df_order = pd.read_sql_query('''select * from [Order]''', engine);
df_order.head(15)
# Out:
# 2019-01-24 18:03:28,429 INFO sqlalchemy.engine.base.Engine select * from [Order]
# INFO:sqlalchemy.engine.base.Engine:select * from [Order]
# 2019-01-24 18:03:28,433 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
#        Id CustomerId  EmployeeId   OrderDate RequiredDate ShippedDate  \
# 0   10248      VINET           5  2012-07-04   2012-08-01  2012-07-16
# 1   10249      TOMSP           6  2012-07-05   2012-08-16  2012-07-10
# 2   10250      HANAR           4  2012-07-08   2012-08-05  2012-07-12
# 3   10251      VICTE           3  2012-07-08   2012-08-05  2012-07-15
# 4   10252      SUPRD           4  2012-07-09   2012-08-06  2012-07-11
# 5   10253      HANAR           3  2012-07-10   2012-07-24  2012-07-16
# 6   10254      CHOPS           5  2012-07-11   2012-08-08  2012-07-23
# 7   10255      RICSU           9  2012-07-12   2012-08-09  2012-07-15
# 8   10256      WELLI           3  2012-07-15   2012-08-12  2012-07-17
# ...

# %%
df_order['ShipRegion'].unique()
# Out:
# array(['Western Europe', 'South America', 'Central America',
#        'North America', 'Northern Europe', 'Scandinavia',
#        'Southern Europe', 'British Isles', 'Eastern Europe'], dtype=object)

# %%
df_order['ShipRegion'].value_counts()
# Out:
# Western Europe     276
# North America      152
# South America      145
# British Isles       75
# Southern Europe     64
# Northern Europe     55
# Scandinavia         28
# Central America     28
# Eastern Europe       7
# Name: ShipRegion, dtype: int64

# %% [markdown]
# #### Total sales in Europe: 402; total sales in the Americas: 325.
# #### How significant is this difference?

# %%
df1_order = pd.read_sql_query('''select ShipRegion, sum(Freight), count(ShipRegion) from [Order] group by ShipRegion''', engine)
df1_order
# Out:
# 2019-01-24 09:14:36,346 INFO sqlalchemy.engine.base.Engine select ShipRegion, sum(Freight), count (ShipRegion) from [Order] group by ShipRegion
# 2019-01-24 09:14:36,349 INFO sqlalchemy.engine.base.Engine ()
#         ShipRegion  sum(Freight)  count (ShipRegion)
# 0    British Isles       5709.51                  75
# 1  Central America       1122.78                  28
# 2   Eastern Europe        175.74                   7
# 3    North America      15969.38                 152
# 4  Northern Europe       4633.79                  55
# 5      Scandinavia       1186.39                  28
# 6    South America       8213.95                 145
# 7  Southern Europe       2369.86                  64
# 8   Western Europe      25561.29                 276

# %%
df1_order.loc[3,:]
# Out:
# ShipRegion            North America
# sum(Freight)                15969.4
# count (ShipRegion)              152
# Name: 3, dtype: object

# %%
df1_order.loc[8,:]
# Out:
# ShipRegion            Western Europe
# sum(Freight)                 25561.3
# count (ShipRegion)               276
# Name: 8, dtype: object

# %%
df2_order = pd.read_sql_query('''select * from [order] where ShipCountry=="USA" group by ShipCity''', engine);
df2_order
# Out:
# 2019-01-24 08:32:14,818 INFO sqlalchemy.engine.base.Engine select * from [order] where ShipCountry=="USA" group by ShipCity
# 2019-01-24 08:32:14,821 INFO sqlalchemy.engine.base.Engine ()
#        Id CustomerId  EmployeeId   OrderDate RequiredDate ShippedDate  \
# 0   11077      RATTC           1  2014-05-06   2014-06-03        None
# 1   11034      OLDWO           8  2014-04-20   2014-06-01  2014-04-27
# 2   11064      SAVEA           1  2014-05-01   2014-05-29  2014-05-04
# 3   11003      THECR           3  2014-04-06   2014-05-04  2014-04-08
# 4   10660      HUNGC           8  2013-09-08   2013-10-06  2013-10-15
# 5   11061      GREAL           4  2014-04-30   2014-06-11        None
# 6   10822      TRAIH           6  2014-01-08   2014-02-05  2014-01-16
# 7   10974      SPLIR           3  2014-03-25   2014-04-08  2014-04-03
# 8   11018      LONEP           4  2014-04-13   2014-05-11  2014-04-16
# 9   10884      LETSS           4  2014-02-12   2014-03-12  2014-02-13
# ...

# %%
df3_order = pd.read_sql_query('''select Id, EmployeeId, Freight from [Order]''', engine)
df3_order

# 830 orders
# Out:
# 2019-01-24 17:37:16,157 INFO sqlalchemy.engine.base.Engine select Id, EmployeeId, Freight from [Order]
# 2019-01-24 17:37:16,159 INFO sqlalchemy.engine.base.Engine ()
#         Id  EmployeeId  Freight
# 0    10248           5    32.38
# 1    10249           6    11.61
# 2    10250           4    65.83
# 3    10251           3    41.34
# 4    10252           4    51.30
# 5    10253           3    58.17
# 6    10254           5    22.98
# 7    10255           9   148.33
# 8    10256           3    13.97
# 9    10257           4    81.91
# 10   10258           1   140.51
# 11   10259           4     3.25
# 12   10260           4    55.09
# 13   10261           4     3.05
# 14   10262           8    48.29
# 15   10263           9   146.06
# 16   10264           6     3.67
# 17   10265           2    55.28
# 18   10266           3    25.73
# 19   10267           4   208.58
# 20   10268           8    66.29
# 21   10269           5     4.56
# 22   10270           1   136.54
# ...

# %%
df31_order = pd.read_sql_query('''select EmployeeId, sum(Freight) as OrderTotal from [Order] group by 
EmployeeId order by OrderTotal ASC''', engine)
df31_order
# Out:
# 2019-01-24 18:00:15,387 INFO sqlalchemy.engine.base.Engine select EmployeeId, sum(Freight) as OrderTotal from [Order] group by
# EmployeeId order by OrderTotal ASC
# INFO:sqlalchemy.engine.base.Engine:select EmployeeId, sum(Freight) as OrderTotal from [Order] group by
# EmployeeId order by OrderTotal ASC
# 2019-01-24 18:00:15,393 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
#    EmployeeId  OrderTotal
# 0           9     3326.26
# 1           6     3780.47
# 2           5     3918.71
# 3           7     6665.44
# 4           8     7487.88
# 5           2     8696.41
# 6           1     8836.64
# 7           3    10884.74
# 8           4    11346.14

# %% [markdown]
# Customer - Employee relation. Is there a preference for an employee?

# %% [markdown]
# -------

# %% [markdown]
# ### Employee

# %%
df_employee = pd.read_sql_query('''select * from [Employee]''', engine);
df_employee
# Out:
# 2019-01-23 14:45:15,137 INFO sqlalchemy.engine.base.Engine select * from [Employee]
# 2019-01-23 14:45:15,139 INFO sqlalchemy.engine.base.Engine ()
#    Id   LastName FirstName                     Title TitleOfCourtesy  \
# 0   1    Davolio     Nancy      Sales Representative             Ms.
# 1   2     Fuller    Andrew     Vice President, Sales             Dr.
# 2   3  Leverling     Janet      Sales Representative             Ms.
# 3   4    Peacock  Margaret      Sales Representative            Mrs.
# 4   5   Buchanan    Steven             Sales Manager             Mr.
# 5   6     Suyama   Michael      Sales Representative             Mr.
# 6   7       King    Robert      Sales Representative             Mr.
# 7   8   Callahan     Laura  Inside Sales Coordinator             Ms.
# 8   9  Dodsworth      Anne      Sales Representative             Ms.
#
#     BirthDate    HireDate                        Address      City  \
# ...

# %%
df_employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 18 columns):
# Id                 9 non-null int64
# LastName           9 non-null object
# FirstName          9 non-null object
# Title              9 non-null object
# TitleOfCourtesy    9 non-null object
# BirthDate          9 non-null object
# HireDate           9 non-null object
# Address            9 non-null object
# City               9 non-null object
# Region             9 non-null object
# PostalCode         9 non-null object
# Country            9 non-null object
# HomePhone          9 non-null object
# Extension          9 non-null object
# Photo              0 non-null object
# Notes              9 non-null object
# ReportsTo          8 non-null float64
# PhotoPath          9 non-null object
# dtypes: float64(1), int64(1), object(16)
# memory usage: 1.3+ KB

# %% [markdown]
# Only 9 employees, who sales most? how they compare?

# %% [markdown]
# ------------

# %% [markdown]
# ### Customer

# %%
df_customer = pd.read_sql_query('''select * from [Customer]''', engine);
df_customer.head(15)
# Out:
# 2019-01-23 14:07:15,433 INFO sqlalchemy.engine.base.Engine select * from [Customer]
# 2019-01-23 14:07:15,434 INFO sqlalchemy.engine.base.Engine ()
#        Id                         CompanyName         ContactName  \
# 0   ALFKI                 Alfreds Futterkiste        Maria Anders
# 1   ANATR  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2   ANTON             Antonio Moreno Taquería      Antonio Moreno
# 3   AROUT                     Around the Horn        Thomas Hardy
# 4   BERGS                  Berglunds snabbköp  Christina Berglund
# 5   BLAUS             Blauer See Delikatessen          Hanna Moos
# 6   BLONP            Blondesddsl père et fils  Frédérique Citeaux
# 7   BOLID           Bólido Comidas preparadas       Martín Sommer
# 8   BONAP                             Bon app    Laurence Lebihan
# 9   BOTTM               Bottom-Dollar Markets   Elizabeth Lincoln
# 10  BSBEV                       B's Beverages   Victoria Ashworth
# ...

# %%
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 11 columns):
# Id              91 non-null object
# CompanyName     91 non-null object
# ContactName     91 non-null object
# ContactTitle    91 non-null object
# Address         91 non-null object
# City            91 non-null object
# Region          91 non-null object
# PostalCode      90 non-null object
# Country         91 non-null object
# Phone           91 non-null object
# Fax             69 non-null object
# dtypes: object(11)
# memory usage: 7.9+ KB

# %% [markdown]
# ----------

# %% [markdown]
# ### Supplier

# %%
df_supplier = pd.read_sql_query('''select * from [Supplier]''', engine);
df_supplier.head(15)
# Out:
# 2019-01-23 14:15:30,677 INFO sqlalchemy.engine.base.Engine select * from [Supplier]
# 2019-01-23 14:15:30,679 INFO sqlalchemy.engine.base.Engine ()
#     Id                             CompanyName                 ContactName  \
# 0    1                          Exotic Liquids            Charlotte Cooper
# 1    2              New Orleans Cajun Delights               Shelley Burke
# 2    3               Grandma Kelly's Homestead               Regina Murphy
# 3    4                           Tokyo Traders                Yoshi Nagase
# 4    5      Cooperativa de Quesos 'Las Cabras'  Antonio del Valle Saavedra
# 5    6                                Mayumi's                 Mayumi Ohno
# 6    7                           Pavlova, Ltd.                 Ian Devling
# 7    8                Specialty Biscuits, Ltd.                Peter Wilson
# 8    9                        PB Knäckebröd AB               Lars Peterson
# 9   10               Refrescos Americanas LTDA                 Carlos Diaz
# ...

# %% [markdown]
# ----------

# %% [markdown]
# ### Region

# %%
df_region = pd.read_sql_query('''select * from [Region]''', engine);
df_region.head(15)
# Out:
# 2019-01-23 14:16:52,801 INFO sqlalchemy.engine.base.Engine select * from [Region]
# 2019-01-23 14:16:52,802 INFO sqlalchemy.engine.base.Engine ()
#    Id RegionDescription
# 0   1           Eastern
# 1   2           Western
# 2   3          Northern
# 3   4          Southern

# %% [markdown]
# --------

# %% [markdown]
# ### Order Detail

# %%
df_orderDetail = pd.read_sql_query('''select * from [OrderDetail]''', engine);
df_orderDetail.head(15)
# Out:
# 2019-01-23 21:37:30,936 INFO sqlalchemy.engine.base.Engine select * from [OrderDetail]
# INFO:sqlalchemy.engine.base.Engine:select * from [OrderDetail]
# 2019-01-23 21:37:30,939 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
#           Id  OrderId  ProductId  UnitPrice  Quantity  Discount
# 0   10248/11    10248         11       14.0        12      0.00
# 1   10248/42    10248         42        9.8        10      0.00
# 2   10248/72    10248         72       34.8         5      0.00
# 3   10249/14    10249         14       18.6         9      0.00
# 4   10249/51    10249         51       42.4        40      0.00
# 5   10250/41    10250         41        7.7        10      0.00
# 6   10250/51    10250         51       42.4        35      0.15
# 7   10250/65    10250         65       16.8        15      0.15
# 8   10251/22    10251         22       16.8         6      0.05
# 9   10251/57    10251         57       15.6        15      0.05
# ...

# %% [markdown]
# -----------

# %% [markdown]
# ### Category

# %%
df_category = pd.read_sql_query('''select * from [Category]''', engine);
df_category
# Out:
# 2019-01-23 14:49:35,430 INFO sqlalchemy.engine.base.Engine select * from [Category]
# 2019-01-23 14:49:35,431 INFO sqlalchemy.engine.base.Engine ()
#    Id    CategoryName                                        Description
# 0   1       Beverages        Soft drinks, coffees, teas, beers, and ales
# 1   2      Condiments  Sweet and savory sauces, relishes, spreads, an...
# 2   3     Confections                Desserts, candies, and sweet breads
# 3   4  Dairy Products                                            Cheeses
# 4   5  Grains/Cereals                Breads, crackers, pasta, and cereal
# 5   6    Meat/Poultry                                     Prepared meats
# 6   7         Produce                          Dried fruit and bean curd
# 7   8         Seafood                                   Seaweed and fish

# %%
#what category sells most and where; maybe decreas or increase prices, change level of dscount?

df1_Cat = pd.read_sql_query('''select Product.CategoryID, Supplier.Region from [Product] join 
[Supplier] on SupplierID group by Region''', engine);
df1_Cat
# Out:
# 2019-01-23 17:21:21,323 INFO sqlalchemy.engine.base.Engine select Product.CategoryID, Supplier.Region from [Product] join
# [Supplier] on SupplierID group by Region
# INFO:sqlalchemy.engine.base.Engine:select Product.CategoryID, Supplier.Region from [Product] join
# [Supplier] on SupplierID group by Region
# 2019-01-23 17:21:21,327 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
#     CategoryId           Region
# 0            2    British Isles
# 1            2     Eastern Asia
# 2            2              NSW
# 3            2    North America
# 4            2  Northern Europe
# 5            2      Scandinavia
# 6            2    South America
# 7            2  South-East Asia
# 8            2  Southern Europe
# 9            2         Victoria
# 10           2   Western Europe

# %% [markdown]
# What category sells most and where; maybe decreas or increase prices, change level of dscount?

# %% [markdown]
# -------

# %% [markdown]
# ### Employee Territory

# %%
df_employeeTerritory = pd.read_sql_query('''select * from [EmployeeTerritory]''', engine);
df_employeeTerritory.head(15)
# Out:
# 2019-01-23 14:19:58,551 INFO sqlalchemy.engine.base.Engine select * from [EmployeeTerritory]
# 2019-01-23 14:19:58,552 INFO sqlalchemy.engine.base.Engine ()
#          Id  EmployeeId TerritoryId
# 0   1/06897           1       06897
# 1   1/19713           1       19713
# 2   2/01581           2       01581
# 3   2/01730           2       01730
# 4   2/01833           2       01833
# 5   2/02116           2       02116
# 6   2/02139           2       02139
# 7   2/02184           2       02184
# 8   2/40222           2       40222
# 9   3/30346           3       30346
# 10  3/31406           3       31406
# 11  3/32859           3       32859
# 12  3/33607           3       33607
# 13  4/20852           4       20852
# 14  4/27403           4       27403

# %% [markdown]
# ---------

# %% [markdown]
# ### Territory

# %%
df_territory = pd.read_sql_query('''select * from [Territory]''', engine);
df_territory.head()
# Out:
# 2019-01-23 17:20:21,593 INFO sqlalchemy.engine.base.Engine select * from [Territory]
# INFO:sqlalchemy.engine.base.Engine:select * from [Territory]
# 2019-01-23 17:20:21,595 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
#       Id TerritoryDescription  RegionId
# 0  01581             Westboro         1
# 1  01730              Bedford         1
# 2  01833            Georgetow         1
# 3  02116               Boston         1
# 4  02139            Cambridge         1

# %% [markdown]
# national - international sales

# %% [markdown]
# -------

# %% [markdown]
# ### Shipper

# %%
df_shipper = pd.read_sql_query('''select * from [Shipper]''', engine);
df_shipper.head(15)
# Out:
# 2019-01-23 14:27:23,646 INFO sqlalchemy.engine.base.Engine select * from [Shipper]
# 2019-01-23 14:27:23,648 INFO sqlalchemy.engine.base.Engine ()
#    Id       CompanyName           Phone
# 0   1    Speedy Express  (503) 555-9831
# 1   2    United Package  (503) 555-3199
# 2   3  Federal Shipping  (503) 555-9931
